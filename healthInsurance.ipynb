# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
healthInsurance = pd.read_csv('Datasets\Indicators_of_Health_Insurance_Coverage_at_the_Time_of_Interview.csv')

# %%
#drop rows with missing values
healthInsurance.dropna(subset=['Value'], inplace=True)
healthInsurance
# Out:
#                                 Indicator              Group          State  \
# 0      Uninsured at the Time of Interview  National Estimate  United States
# 1      Uninsured at the Time of Interview             By Age  United States
# 2      Uninsured at the Time of Interview             By Age  United States
# 3      Uninsured at the Time of Interview             By Age  United States
# 4      Uninsured at the Time of Interview             By Age  United States
# ...                                   ...                ...            ...
# 11704   Private Health Insurance Coverage           By State       Virginia
# 11705   Private Health Insurance Coverage           By State     Washington
# 11706   Private Health Insurance Coverage           By State  West Virginia
# 11707   Private Health Insurance Coverage           By State      Wisconsin
# 11708   Private Health Insurance Coverage           By State        Wyoming
#
# ...

# %%
#drop unnecessary columns
healthInsurance.drop(['Low CI', 'High CI', 'Confidence Interval', 'Quartile Range', 'Quartile Number', 
'Suppression Flag'], axis=1, inplace=True)
healthInsurance
# Out:
#                                 Indicator              Group          State  \
# 0      Uninsured at the Time of Interview  National Estimate  United States
# 1      Uninsured at the Time of Interview             By Age  United States
# 2      Uninsured at the Time of Interview             By Age  United States
# 3      Uninsured at the Time of Interview             By Age  United States
# 4      Uninsured at the Time of Interview             By Age  United States
# ...                                   ...                ...            ...
# 11704   Private Health Insurance Coverage           By State       Virginia
# 11705   Private Health Insurance Coverage           By State     Washington
# 11706   Private Health Insurance Coverage           By State  West Virginia
# 11707   Private Health Insurance Coverage           By State      Wisconsin
# 11708   Private Health Insurance Coverage           By State        Wyoming
#
# ...

# %%
#group by state, year, indicator, phase, and value
healthInsurance = healthInsurance.groupby(['State', 'Indicator'])['Value'].sum()
healthInsurance
# Out:
# State      Indicator
# Alabama    Private Health Insurance Coverage     4076.5
#            Public Health Insurance Coverage      1183.9
#            Uninsured at the Time of Interview     712.3
# Alaska     Private Health Insurance Coverage     3826.1
#            Public Health Insurance Coverage      1387.3
#                                                   ...
# Wisconsin  Public Health Insurance Coverage      1022.8
#            Uninsured at the Time of Interview     333.3
# Wyoming    Private Health Insurance Coverage     4127.6
#            Public Health Insurance Coverage       883.5
#            Uninsured at the Time of Interview     791.5
# Name: Value, Length: 156, dtype: float64

# %%
#remove united states
healthInsurance = healthInsurance.drop('United States')
healthInsurance
# Out:
# State      Indicator
# Alabama    Private Health Insurance Coverage     4076.5
#            Public Health Insurance Coverage      1183.9
#            Uninsured at the Time of Interview     712.3
# Alaska     Private Health Insurance Coverage     3826.1
#            Public Health Insurance Coverage      1387.3
#                                                   ...
# Wisconsin  Public Health Insurance Coverage      1022.8
#            Uninsured at the Time of Interview     333.3
# Wyoming    Private Health Insurance Coverage     4127.6
#            Public Health Insurance Coverage       883.5
#            Uninsured at the Time of Interview     791.5
# Name: Value, Length: 153, dtype: float64

# %%
#unstack data
healthInsurance = healthInsurance.unstack()
healthInsurance
# Out:
# Indicator             Private Health Insurance Coverage  \
# State
# Alabama                                          4076.5
# Alaska                                           3826.1
# Arizona                                          3817.4
# Arkansas                                         3814.5
# California                                       3885.2
# Colorado                                         4106.8
# Connecticut                                      4192.9
# Delaware                                         4139.9
# District of Columbia                             4326.2
# Florida                                          3977.5
# Georgia                                          3942.6
# Hawaii                                           4286.1
# Idaho                                            4000.6
# Illinois                                         4159.3
# Indiana                                          4049.4
# Iowa                                             4210.9
# ...

# %%
#normalize data
healthInsurance = healthInsurance.div(healthInsurance.sum(axis=1), axis=0)
healthInsurance
# Out:
# Indicator             Private Health Insurance Coverage  \
# State
# Alabama                                        0.682522
# Alaska                                         0.647712
# Arizona                                        0.657923
# Arkansas                                       0.633827
# California                                     0.661187
# Colorado                                       0.710765
# Connecticut                                    0.729936
# Delaware                                       0.715441
# District of Columbia                           0.770650
# Florida                                        0.673605
# Georgia                                        0.666791
# Hawaii                                         0.724738
# Idaho                                          0.683688
# Illinois                                       0.723772
# Indiana                                        0.697367
# Iowa                                           0.732190
# ...

# %%
#convert to csv
healthInsurance.to_csv('Datasets\healthInsurance.csv')
