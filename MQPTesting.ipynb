# %%
import pandas as pd
import matplotlib.pyplot as plt

covid = pd.read_csv("Archive__COVID-19_Vaccination_Demographic_Trends_by_Report_Date__National.csv")
covid
# Out:
#                         Date Demographic_category  Administered_Dose1  \
# 0     08/15/2021 12:00:00 AM          Age_unknown               21642
# 1     11/17/2021 12:00:00 AM            Age_known           210004814
# 2     11/17/2021 12:00:00 AM          Age_unknown               23646
# 3     11/17/2021 12:00:00 AM          Ages_<12yrs             1946263
# 4     11/17/2021 12:00:00 AM          Ages_<18yrs            15658033
# ...                      ...                  ...                 ...
# 9443  12/14/2020 12:00:00 AM       Race_eth_known                   0
# 9444  12/13/2020 12:00:00 AM            Sex_known                   0
# 9445  12/13/2020 12:00:00 AM       Race_eth_known                   0
# 9446  12/13/2020 12:00:00 AM                   US                   0
# 9447  12/13/2020 12:00:00 AM            Age_known                   0
#
#       Series_Complete_Yes  Administered_Dose1_pct_agegroup  \
# 0                    4921                              0.0
# ...

# %%
covid.head(18)
# Out:
#                       Date Demographic_category  Administered_Dose1  \
# 0   08/15/2021 12:00:00 AM          Age_unknown               21642
# 1   11/17/2021 12:00:00 AM            Age_known           210004814
# 2   11/17/2021 12:00:00 AM          Age_unknown               23646
# 3   11/17/2021 12:00:00 AM          Ages_<12yrs             1946263
# 4   11/17/2021 12:00:00 AM          Ages_<18yrs            15658033
# 5   11/17/2021 12:00:00 AM       Ages_12-15_yrs             8831424
# 6   11/17/2021 12:00:00 AM       Ages_16-17_yrs             4880346
# 7   11/17/2021 12:00:00 AM       Ages_18-24_yrs            18773084
# 8   11/17/2021 12:00:00 AM       Ages_18-29_yrs            32874378
# 9   11/17/2021 12:00:00 AM       Ages_25-39_yrs            44240975
# 10  11/17/2021 12:00:00 AM       Ages_30-39_yrs            30139681
# 11  11/17/2021 12:00:00 AM       Ages_40-49_yrs            29393932
# 12  11/17/2021 12:00:00 AM       Ages_50-64_yrs            50830993
# ...

# %%
covid_age = covid.iloc[3:15]
covid_age = covid_age.reset_index(drop=True)


s = covid_age['Demographic_category'].str.slice(start=5)
covid_age['Age_Group'] = s

covid_age
# Out:
#                       Date Demographic_category  Administered_Dose1  \
# 0   11/17/2021 12:00:00 AM          Ages_<12yrs             1946263
# 1   11/17/2021 12:00:00 AM          Ages_<18yrs            15658033
# 2   11/17/2021 12:00:00 AM       Ages_12-15_yrs             8831424
# 3   11/17/2021 12:00:00 AM       Ages_16-17_yrs             4880346
# 4   11/17/2021 12:00:00 AM       Ages_18-24_yrs            18773084
# 5   11/17/2021 12:00:00 AM       Ages_18-29_yrs            32874378
# 6   11/17/2021 12:00:00 AM       Ages_25-39_yrs            44240975
# 7   11/17/2021 12:00:00 AM       Ages_30-39_yrs            30139681
# 8   11/17/2021 12:00:00 AM       Ages_40-49_yrs            29393932
# 9   11/17/2021 12:00:00 AM       Ages_50-64_yrs            50830993
# 10  11/17/2021 12:00:00 AM       Ages_65-74_yrs            30385827
# 11  11/17/2021 12:00:00 AM         Ages_75+_yrs            20721970
#
#     Series_Complete_Yes  Administered_Dose1_pct_agegroup  \
# ...

# %%
covid_age.plot( x = 'Age_Group', y = 'Series_Complete_Pop_pct_agegroup')
# Out:
# <AxesSubplot:xlabel='Age_Group'>
