# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Datasets/Provisional_COVID-19_Death_Counts_in_the_United_States_by_County.csv")
countyIncome = pd.read_csv("Datasets/countyincome.csv")

df["County name"] = df["County name"].str.replace("\sCounty", "")
df["County name"] = df["County name"].str.replace("\sParish", "")
df["County name"] = df["County name"].str.replace("\scity", "")

df = df.rename({'County name': 'County'}, axis=1)
# Out:
# C:\Users\trans\AppData\Local\Temp\ipykernel_23084\797231761.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["County name"] = df["County name"].str.replace("\sCounty", "")
# C:\Users\trans\AppData\Local\Temp\ipykernel_23084\797231761.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["County name"] = df["County name"].str.replace("\sParish", "")
# C:\Users\trans\AppData\Local\Temp\ipykernel_23084\797231761.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["County name"] = df["County name"].str.replace("\scity", "")

# %%
countyIncome = countyIncome[countyIncome.County != "Alabama"]
countyIncome = countyIncome[countyIncome.County != "Alaska"]
countyIncome = countyIncome[countyIncome.County != "Arizona"]
countyIncome = countyIncome[countyIncome.County != "Arkansas"]
countyIncome = countyIncome[countyIncome.County != "California"]
countyIncome = countyIncome[countyIncome.County != "Colorado"]
countyIncome = countyIncome[countyIncome.County != "Connecticut"]
countyIncome = countyIncome[countyIncome.County != "Delaware"]
countyIncome = countyIncome[countyIncome.County != "Florida"]
countyIncome = countyIncome[countyIncome.County != "Georgia"]
countyIncome = countyIncome[countyIncome.County != "Hawaii"]
countyIncome = countyIncome[countyIncome.County != "Idaho"]
countyIncome = countyIncome[countyIncome.County != "Illinois"]
countyIncome = countyIncome[countyIncome.County != "Indiana"]
countyIncome = countyIncome[countyIncome.County != "Iowa"]
countyIncome = countyIncome[countyIncome.County != "Kansas"]
countyIncome = countyIncome[countyIncome.County != "Kentucky"]
countyIncome = countyIncome[countyIncome.County != "Louisiana"]
countyIncome = countyIncome[countyIncome.County != "Maine"]
countyIncome = countyIncome[countyIncome.County != "Maryland"]
countyIncome = countyIncome[countyIncome.County != "Massachusetts"]
countyIncome = countyIncome[countyIncome.County != "Michigan"]
countyIncome = countyIncome[countyIncome.County != "Minnesota"]
countyIncome = countyIncome[countyIncome.County != "Mississippi"]
countyIncome = countyIncome[countyIncome.County != "Missouri"]
countyIncome = countyIncome[countyIncome.County != "Montana"]
countyIncome = countyIncome[countyIncome.County != "Nebraska"]
countyIncome = countyIncome[countyIncome.County != "Nevada"]
countyIncome = countyIncome[countyIncome.County != "New Hampshire"]
countyIncome = countyIncome[countyIncome.County != "New Jersey"]
countyIncome = countyIncome[countyIncome.County != "New Mexico"]
countyIncome = countyIncome[countyIncome.County != "New York"]
countyIncome = countyIncome[countyIncome.County != "North Carolina"]
countyIncome = countyIncome[countyIncome.County != "North Dakota"]
countyIncome = countyIncome[countyIncome.County != "Ohio"]
countyIncome = countyIncome[countyIncome.County != "Oklahoma"]
countyIncome = countyIncome[countyIncome.County != "Oregon"]
countyIncome = countyIncome[countyIncome.County != "Pennsylvania"]
countyIncome = countyIncome[countyIncome.County != "Rhode Island"]
countyIncome = countyIncome[countyIncome.County != "South Carolina"]
countyIncome = countyIncome[countyIncome.County != "South Dakota"]
countyIncome = countyIncome[countyIncome.County != "Tennessee"]
countyIncome = countyIncome[countyIncome.County != "Texas"]
countyIncome = countyIncome[countyIncome.County != "Utah"]
countyIncome = countyIncome[countyIncome.County != "Vermont"]
countyIncome = countyIncome[countyIncome.County != "Virginia"]
countyIncome = countyIncome[countyIncome.County != "Washington"]
countyIncome = countyIncome[countyIncome.County != "West Virginia"]
countyIncome = countyIncome[countyIncome.County != "Wisconsin"]
countyIncome = countyIncome[countyIncome.County != "Wyoming"]
countyIncome = countyIncome[countyIncome.County != "United States"]

df = df[df.County != "Alabama"]
df = df[df.County != "Alaska"]
df = df[df.County != "Arizona"]
df = df[df.County != "Arkansas"]
df = df[df.County != "California"]
df = df[df.County != "Colorado"]
df = df[df.County != "Connecticut"]
df = df[df.County != "Delaware"]
df = df[df.County != "Florida"]
df = df[df.County != "Georgia"]
df = df[df.County != "Hawaii"]
df = df[df.County != "Idaho"]
df = df[df.County != "Illinois"]
df = df[df.County != "Indiana"]
df = df[df.County != "Iowa"]
df = df[df.County != "Kansas"]
df = df[df.County != "Kentucky"]
df = df[df.County != "Louisiana"]
df = df[df.County != "Maine"]
df = df[df.County != "Maryland"]
df = df[df.County != "Massachusetts"]
df = df[df.County != "Michigan"]
df = df[df.County != "Minnesota"]
df = df[df.County != "Mississippi"]
df = df[df.County != "Missouri"]
df = df[df.County != "Montana"]
df = df[df.County != "Nebraska"]
df = df[df.County != "Nevada"]
df = df[df.County != "New Hampshire"]
df = df[df.County != "New Jersey"]
df = df[df.County != "New Mexico"]
df = df[df.County != "New York"]
df = df[df.County != "North Carolina"]
df = df[df.County != "North Dakota"]
df = df[df.County != "Ohio"]
df = df[df.County != "Oklahoma"]
df = df[df.County != "Oregon"]
df = df[df.County != "Pennsylvania"]
df = df[df.County != "Rhode Island"]
df = df[df.County != "South Carolina"]
df = df[df.County != "South Dakota"]
df = df[df.County != "Tennessee"]
df = df[df.County != "Texas"]
df = df[df.County != "Utah"]
df = df[df.County != "Vermont"]
df = df[df.County != "Virginia"]
df = df[df.County != "Washington"]
df = df[df.County != "West Virginia"]
df = df[df.County != "Wisconsin"]
df = df[df.County != "Wyoming"]
df = df[df.County != "United States"]


countyIncome = countyIncome.replace('Valdez-Cordova Census Area2', 'Valdez-Cordova Census Area')
countyIncome = countyIncome.replace('Lagrange', 'LaGrange')
countyIncome = countyIncome.replace('Doña Ana', 'Dona Ana')
countyIncome = countyIncome.replace('Petersburg Borough', 'Petersburg Census Area')
df = df.replace('Wade Hampton Census Area', 'Kusilvak Census Area')

countyIncome = countyIncome.assign(County = countyIncome['County'].str.split(',')).explode('County')
countyIncome = countyIncome.assign(County = countyIncome['County'].str.split('+')).explode('County')
countyIncome['County'] = countyIncome['County'].str.strip()

# %%
#np.setdiff1d(df["County"], countyIncome['County'])
#np.setdiff1d(countyIncome['County'], df["County"])
countyIncome = countyIncome.rename({'County': 'County'}, axis=1)

# %%
incomeAndDeaths = df.merge(countyIncome, on='County', how='inner')
#incomeAndDeaths.to_csv("Covid Deaths by County Income.csv")

incomeAndDeaths2 = incomeAndDeaths[['2019', '2020', '2021', 'Deaths involving COVID-19']]

# %%
incomeAndDeaths2 = incomeAndDeaths2.dropna(axis=0)
incomeAndDeaths2['2020'] = incomeAndDeaths2['2020'].str.extract('(\d+)', expand=False)
incomeAndDeaths2['2021'] = incomeAndDeaths2['2021'].str.extract('(\d+)', expand=False)

incomeAndDeaths2['2020'] = incomeAndDeaths2['2020'].astype(int)
incomeAndDeaths2['2021'] = incomeAndDeaths2['2021'].astype(int)

incomeAndDeaths2 = incomeAndDeaths2.rename(columns={'Deaths involving COVID-19': 'COVID-19 Deaths'})

# %%
import seaborn as sn
import matplotlib.pyplot as plt

corr_mat = incomeAndDeaths2.corr()
sn.heatmap(corr_mat, annot=True)
plt.rcParams['figure.dpi'] = 500
plt.show()

# %%
incomeAndDeaths2.to_csv('Datasets/incomeanddeaths.csv', index=False)
